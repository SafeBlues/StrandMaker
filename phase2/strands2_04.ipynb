# %% [markdown]
# ## Strands for Phase 2, release 0.04 (2.04)
#
# 600 strands in total
#
# This release is identical to 2.03 but with a one week delay.

# %%
strengthArray = [0.08, 0.16, 0.48]
radiusArray = [30, 35, 40, 45, 50, 60, 70, 80, 90, 100]
numRepeats_SIR_SEIR = 4; 
numRepeats_SI_SEI = 2;

# %%
function createRepeats(parentStrand::Dict{Symbol,String}, num)
    strands = Array{Dict{Symbol,String}}(undef,0)
    for s in strengthArray, r in radiusArray, n in 1:num
        strand = deepcopy(parentStrand)
        strand[:name] = strand[:name]*"-($s,$r)-repeat$n"
        strand[:strength] = "$s"
        strand[:radius] = "$r"
        push!(strands,strand)
    end
    strands
end;

# %%
baseStrand = Dict{Symbol,String}()
baseStrand[:seedTime] = "2021-09-01T21:00:00Z" #9am on Thursday morning Sep 02 (in Auckland)
baseStrand[:endTime] = "2021-11-04T20:00:00Z"#9pm in the evening of Nov 4 (in Auckland)
baseStrand[:minimumAppVersion] = "60";

# %%
### SEI epidemics
SEIstrand = deepcopy(baseStrand)
SEIstrand[:name] = "2.04-SEI"
SEIstrand[:seedingProbability] = "0.1"
SEIstrand[:incubationMean] = "172800" #default for two days incubation
SEIstrand[:incubationShape] = "3"
SEIstrand[:infectionMean] = "31536000" #365 days
SEIstrand[:infectiousPeriodShape] = "10000";
SEIstrand
# Out:
# Dict{Symbol, String} with 9 entries:
#   :infectionMean         => "31536000"
#   :endTime               => "2021-11-04T20:00:00Z"
#   :incubationShape       => "3"
#   :minimumAppVersion     => "60"
#   :name                  => "2.04-SEI"
#   :seedingProbability    => "0.1"
#   :infectiousPeriodShape => "10000"
#   :seedTime              => "2021-09-01T21:00:00Z"
#   :incubationMean        => "172800"

# %%
##SI
SIstrand = deepcopy(SEIstrand)
SIstrand[:name] = "2.04-SI"
SIstrand[:incubationMean] = "1" #1 second incubation
SIstrand[:incubationShape] = "10000"
SIstrand
# Out:
# Dict{Symbol, String} with 9 entries:
#   :infectionMean         => "31536000"
#   :endTime               => "2021-11-04T20:00:00Z"
#   :incubationShape       => "10000"
#   :minimumAppVersion     => "60"
#   :name                  => "2.04-SI"
#   :seedingProbability    => "0.1"
#   :infectiousPeriodShape => "10000"
#   :seedTime              => "2021-09-01T21:00:00Z"
#   :incubationMean        => "1"

# %%
#The base strand for the SEIR epidemics
SEIRstrand = deepcopy(baseStrand)
SEIRstrand[:name] = "2.04-SEIR"
SEIRstrand[:seedingProbability] = "0.1"
SEIRstrand[:incubationMean] = "172800" 
SEIRstrand[:incubationShape] = "3"
SEIRstrand[:infectionMean] = "432000" #5 days should vary
SEIRstrand[:infectiousPeriodShape] = "3";
SEIRstrand
# Out:
# Dict{Symbol, String} with 9 entries:
#   :infectionMean         => "432000"
#   :endTime               => "2021-11-04T20:00:00Z"
#   :incubationShape       => "3"
#   :minimumAppVersion     => "60"
#   :name                  => "2.04-SEIR"
#   :seedingProbability    => "0.1"
#   :infectiousPeriodShape => "3"
#   :seedTime              => "2021-09-01T21:00:00Z"
#   :incubationMean        => "172800"

# %%
##SIR base strand
SIRstrand = deepcopy(SEIRstrand)
SIRstrand[:name] = "2.04-SIR"
SIRstrand[:incubationMean] = "1" #1 second incubation
SIRstrand[:incubationShape] = "10000"
SIRstrand
# Out:
# Dict{Symbol, String} with 9 entries:
#   :infectionMean         => "432000"
#   :endTime               => "2021-11-04T20:00:00Z"
#   :incubationShape       => "10000"
#   :minimumAppVersion     => "60"
#   :name                  => "2.04-SIR"
#   :seedingProbability    => "0.1"
#   :infectiousPeriodShape => "3"
#   :seedTime              => "2021-09-01T21:00:00Z"
#   :incubationMean        => "1"

# %%
SEIRstrandShortDuration = deepcopy(SEIRstrand)
SEIRstrandShortDuration[:name] = SEIRstrandShortDuration[:name]*"-days5";
SEIRstrandShortDuration
# Out:
# Dict{Symbol, String} with 9 entries:
#   :infectionMean         => "432000"
#   :endTime               => "2021-11-04T20:00:00Z"
#   :incubationShape       => "3"
#   :minimumAppVersion     => "60"
#   :name                  => "2.04-SEIR-days5"
#   :seedingProbability    => "0.1"
#   :infectiousPeriodShape => "3"
#   :seedTime              => "2021-09-01T21:00:00Z"
#   :incubationMean        => "172800"

# %%
SEIRstrandLongDuration = deepcopy(SEIRstrand)
SEIRstrandLongDuration[:infectionMean] = "864000" #10 days 
SEIRstrandLongDuration[:name] = SEIRstrandLongDuration[:name]*"-days10";
SEIRstrandLongDuration
# Out:
# Dict{Symbol, String} with 9 entries:
#   :infectionMean         => "864000"
#   :endTime               => "2021-11-04T20:00:00Z"
#   :incubationShape       => "3"
#   :minimumAppVersion     => "60"
#   :name                  => "2.04-SEIR-days10"
#   :seedingProbability    => "0.1"
#   :infectiousPeriodShape => "3"
#   :seedTime              => "2021-09-01T21:00:00Z"
#   :incubationMean        => "172800"

# %%
SIRstrandShortDuration = deepcopy(SIRstrand)
SIRstrandShortDuration[:name] = SIRstrandShortDuration[:name]*"-days5";
SIRstrandShortDuration
# Out:
# Dict{Symbol, String} with 9 entries:
#   :infectionMean         => "432000"
#   :endTime               => "2021-11-04T20:00:00Z"
#   :incubationShape       => "10000"
#   :minimumAppVersion     => "60"
#   :name                  => "2.04-SIR-days5"
#   :seedingProbability    => "0.1"
#   :infectiousPeriodShape => "3"
#   :seedTime              => "2021-09-01T21:00:00Z"
#   :incubationMean        => "1"

# %%
SIRstrandLongDuration = deepcopy(SIRstrand)
SIRstrandLongDuration[:infectionMean] = "864000" #10 days 
SIRstrandLongDuration[:name] = SIRstrandLongDuration[:name]*"-days10";
SIRstrandLongDuration
# Out:
# Dict{Symbol, String} with 9 entries:
#   :infectionMean         => "864000"
#   :endTime               => "2021-11-04T20:00:00Z"
#   :incubationShape       => "10000"
#   :minimumAppVersion     => "60"
#   :name                  => "2.04-SIR-days10"
#   :seedingProbability    => "0.1"
#   :infectiousPeriodShape => "3"
#   :seedTime              => "2021-09-01T21:00:00Z"
#   :incubationMean        => "1"

# %%
#An array that will hold all strands
strands = Array{Dict{Symbol,String}}(undef,0)
append!(strands, createRepeats(SIstrand, numRepeats_SI_SEI))
append!(strands, createRepeats(SEIstrand, numRepeats_SI_SEI))
append!(strands, createRepeats(SEIRstrandShortDuration, numRepeats_SIR_SEIR))
append!(strands, createRepeats(SEIRstrandLongDuration, numRepeats_SIR_SEIR))
append!(strands, createRepeats(SIRstrandShortDuration, numRepeats_SIR_SEIR))
append!(strands, createRepeats(SIRstrandLongDuration, numRepeats_SIR_SEIR));

# %%
length(strands)
# Out:
# 600

# %%
function strandJSON(sd::Dict{Symbol,String})
    str = """
        {\"name\":\"$(sd[:name])\",
         \"seedingProbability\":\"$(sd[:seedingProbability])\",
         \"infectionProbabilityMapP\":\"$(sd[:strength])\",
         \"infectionProbabilityMapK\":\"$(sd[:radius])\",
         \"infectionProbabilityMapL\":\"1000000\",
         \"incubationPeriodMeanSec\":\"$(sd[:incubationMean])\",
         \"incubationPeriodShape\":\"$(sd[:incubationShape])\",
         \"infectiousPeriodMeanSec\":\"$(sd[:infectionMean])\",
         \"infectiousPeriodShape\":\"$(sd[:infectiousPeriodShape])\",
         \"startTime\":\"$(sd[:seedTime])\",
         \"endTime\":\"$(sd[:endTime])\",
         \"minimumAppVersion\":\"$(sd[:minimumAppVersion])\"}
    """
    join(map(x -> isspace(str[x]) ? "" : str[x], 1:length(str))) #how the $%@$% to remove white space in Julia strings?
end

strandStrings = strandJSON.(strands)
if length(filter(x->x=="strands2_04.txt",map(abspath, readdir())))!=0
    rm("strands2_04.txt") #remove the text file in the working directory if exists
end
touch("strands2_04.txt") #create the text file in the working directory
open("strands2_04.txt","w") do file 
    newID = 2365 #last strand in system
    for s in strandStrings
        newID +=1
        write(file,"$newID: $s\n")
        println("$newID: $s\n")
    end
end
# Out:
# 2366: {"name":"2.04-SI-(0.08,30)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"30","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2367: {"name":"2.04-SI-(0.08,30)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"30","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2368: {"name":"2.04-SI-(0.08,35)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"35","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2369: {"name":"2.04-SI-(0.08,35)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"35","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2370: {"name":"2.04-SI-(0.08,40)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"40","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2371: {"name":"2.04-SI-(0.08,40)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"40","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2372: {"name":"2.04-SI-(0.08,45)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"45","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2373: {"name":"2.04-SI-(0.08,45)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"45","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2374: {"name":"2.04-SI-(0.08,50)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"50","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2375: {"name":"2.04-SI-(0.08,50)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"50","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2376: {"name":"2.04-SI-(0.08,60)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"60","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2377: {"name":"2.04-SI-(0.08,60)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"60","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2378: {"name":"2.04-SI-(0.08,70)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"70","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2379: {"name":"2.04-SI-(0.08,70)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"70","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2380: {"name":"2.04-SI-(0.08,80)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"80","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2381: {"name":"2.04-SI-(0.08,80)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"80","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2382: {"name":"2.04-SI-(0.08,90)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"90","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2383: {"name":"2.04-SI-(0.08,90)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"90","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2384: {"name":"2.04-SI-(0.08,100)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"100","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2385: {"name":"2.04-SI-(0.08,100)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"100","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2386: {"name":"2.04-SI-(0.16,30)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"30","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2387: {"name":"2.04-SI-(0.16,30)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"30","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2388: {"name":"2.04-SI-(0.16,35)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"35","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2389: {"name":"2.04-SI-(0.16,35)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"35","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2390: {"name":"2.04-SI-(0.16,40)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"40","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2391: {"name":"2.04-SI-(0.16,40)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"40","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
# 2392: {"name":"2.04-SI-(0.16,45)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"45","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2393: {"name":"2.04-SI-(0.16,45)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"45","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2394: {"name":"2.04-SI-(0.16,50)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"50","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2395: {"name":"2.04-SI-(0.16,50)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"50","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2396: {"name":"2.04-SI-(0.16,60)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"60","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2397: {"name":"2.04-SI-(0.16,60)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"60","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2398: {"name":"2.04-SI-(0.16,70)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"70","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2399: {"name":"2.04-SI-(0.16,70)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"70","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2400: {"name":"2.04-SI-(0.16,80)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"80","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2401: {"name":"2.04-SI-(0.16,80)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"80","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2402: {"name":"2.04-SI-(0.16,90)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"90","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2403: {"name":"2.04-SI-(0.16,90)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"90","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2404: {"name":"2.04-SI-(0.16,100)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"100","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2405: {"name":"2.04-SI-(0.16,100)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"100","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2406: {"name":"2.04-SI-(0.48,30)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"30","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2407: {"name":"2.04-SI-(0.48,30)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"30","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2408: {"name":"2.04-SI-(0.48,35)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"35","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2409: {"name":"2.04-SI-(0.48,35)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"35","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2410: {"name":"2.04-SI-(0.48,40)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"40","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2411: {"name":"2.04-SI-(0.48,40)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"40","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2412: {"name":"2.04-SI-(0.48,45)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"45","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2413: {"name":"2.04-SI-(0.48,45)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"45","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2414: {"name":"2.04-SI-(0.48,50)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"50","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2415: {"name":"2.04-SI-(0.48,50)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"50","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2416: {"name":"2.04-SI-(0.48,60)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"60","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2417: {"name":"2.04-SI-(0.48,60)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"60","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
# 2418: {"name":"2.04-SI-(0.48,70)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"70","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2419: {"name":"2.04-SI-(0.48,70)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"70","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2420: {"name":"2.04-SI-(0.48,80)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"80","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2421: {"name":"2.04-SI-(0.48,80)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"80","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2422: {"name":"2.04-SI-(0.48,90)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"90","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2423: {"name":"2.04-SI-(0.48,90)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"90","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2424: {"name":"2.04-SI-(0.48,100)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"100","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2425: {"name":"2.04-SI-(0.48,100)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"100","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2426: {"name":"2.04-SEI-(0.08,30)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"30","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2427: {"name":"2.04-SEI-(0.08,30)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"30","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2428: {"name":"2.04-SEI-(0.08,35)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"35","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2429: {"name":"2.04-SEI-(0.08,35)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"35","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2430: {"name":"2.04-SEI-(0.08,40)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"40","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2431: {"name":"2.04-SEI-(0.08,40)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"40","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2432: {"name":"2.04-SEI-(0.08,45)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"45","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2433: {"name":"2.04-SEI-(0.08,45)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"45","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2434: {"name":"2.04-SEI-(0.08,50)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"50","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2435: {"name":"2.04-SEI-(0.08,50)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"50","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2436: {"name":"2.04-SEI-(0.08,60)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"60","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2437: {"name":"2.04-SEI-(0.08,60)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"60","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2438: {"name":"2.04-SEI-(0.08,70)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"70","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2439: {"name":"2.04-SEI-(0.08,70)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"70","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2440: {"name":"2.04-SEI-(0.08,80)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"80","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2441: {"name":"2.04-SEI-(0.08,80)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"80","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2442: {"name":"2.04-SEI-(0.08,90)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"90","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2443: {"name":"2.04-SEI-(0.08,90)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"90","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
# 2444: {"name":"2.04-SEI-(0.08,100)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"100","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2445: {"name":"2.04-SEI-(0.08,100)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"100","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2446: {"name":"2.04-SEI-(0.16,30)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"30","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2447: {"name":"2.04-SEI-(0.16,30)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"30","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2448: {"name":"2.04-SEI-(0.16,35)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"35","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2449: {"name":"2.04-SEI-(0.16,35)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"35","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2450: {"name":"2.04-SEI-(0.16,40)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"40","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2451: {"name":"2.04-SEI-(0.16,40)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"40","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2452: {"name":"2.04-SEI-(0.16,45)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"45","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2453: {"name":"2.04-SEI-(0.16,45)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"45","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2454: {"name":"2.04-SEI-(0.16,50)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"50","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2455: {"name":"2.04-SEI-(0.16,50)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"50","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2456: {"name":"2.04-SEI-(0.16,60)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"60","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2457: {"name":"2.04-SEI-(0.16,60)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"60","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2458: {"name":"2.04-SEI-(0.16,70)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"70","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2459: {"name":"2.04-SEI-(0.16,70)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"70","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2460: {"name":"2.04-SEI-(0.16,80)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"80","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2461: {"name":"2.04-SEI-(0.16,80)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"80","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2462: {"name":"2.04-SEI-(0.16,90)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"90","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2463: {"name":"2.04-SEI-(0.16,90)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"90","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2464: {"name":"2.04-SEI-(0.16,100)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"100","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2465: {"name":"2.04-SEI-(0.16,100)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"100","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2466: {"name":"2.04-SEI-(0.48,30)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"30","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2467: {"name":"2.04-SEI-(0.48,30)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"30","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2468: {"name":"2.04-SEI-(0.48,35)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"35","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2469: {"name":"2.04-SEI-(0.48,35)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"35","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
# 2470: {"name":"2.04-SEI-(0.48,40)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"40","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2471: {"name":"2.04-SEI-(0.48,40)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"40","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2472: {"name":"2.04-SEI-(0.48,45)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"45","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2473: {"name":"2.04-SEI-(0.48,45)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"45","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2474: {"name":"2.04-SEI-(0.48,50)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"50","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2475: {"name":"2.04-SEI-(0.48,50)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"50","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2476: {"name":"2.04-SEI-(0.48,60)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"60","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2477: {"name":"2.04-SEI-(0.48,60)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"60","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2478: {"name":"2.04-SEI-(0.48,70)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"70","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2479: {"name":"2.04-SEI-(0.48,70)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"70","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2480: {"name":"2.04-SEI-(0.48,80)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"80","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2481: {"name":"2.04-SEI-(0.48,80)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"80","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2482: {"name":"2.04-SEI-(0.48,90)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"90","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2483: {"name":"2.04-SEI-(0.48,90)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"90","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2484: {"name":"2.04-SEI-(0.48,100)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"100","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2485: {"name":"2.04-SEI-(0.48,100)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"100","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# ...
#
# 2927: {"name":"2.04-SIR-days10-(0.48,30)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"30","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2928: {"name":"2.04-SIR-days10-(0.48,30)-repeat3","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"30","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2929: {"name":"2.04-SIR-days10-(0.48,30)-repeat4","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"30","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2930: {"name":"2.04-SIR-days10-(0.48,35)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"35","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2931: {"name":"2.04-SIR-days10-(0.48,35)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"35","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2932: {"name":"2.04-SIR-days10-(0.48,35)-repeat3","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"35","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2933: {"name":"2.04-SIR-days10-(0.48,35)-repeat4","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"35","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2934: {"name":"2.04-SIR-days10-(0.48,40)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"40","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2935: {"name":"2.04-SIR-days10-(0.48,40)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"40","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2936: {"name":"2.04-SIR-days10-(0.48,40)-repeat3","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"40","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2937: {"name":"2.04-SIR-days10-(0.48,40)-repeat4","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"40","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
# 2938: {"name":"2.04-SIR-days10-(0.48,45)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"45","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2939: {"name":"2.04-SIR-days10-(0.48,45)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"45","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2940: {"name":"2.04-SIR-days10-(0.48,45)-repeat3","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"45","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2941: {"name":"2.04-SIR-days10-(0.48,45)-repeat4","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"45","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2942: {"name":"2.04-SIR-days10-(0.48,50)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"50","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2943: {"name":"2.04-SIR-days10-(0.48,50)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"50","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2944: {"name":"2.04-SIR-days10-(0.48,50)-repeat3","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"50","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2945: {"name":"2.04-SIR-days10-(0.48,50)-repeat4","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"50","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2946: {"name":"2.04-SIR-days10-(0.48,60)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"60","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2947: {"name":"2.04-SIR-days10-(0.48,60)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"60","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2948: {"name":"2.04-SIR-days10-(0.48,60)-repeat3","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"60","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2949: {"name":"2.04-SIR-days10-(0.48,60)-repeat4","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"60","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2950: {"name":"2.04-SIR-days10-(0.48,70)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"70","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2951: {"name":"2.04-SIR-days10-(0.48,70)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"70","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2952: {"name":"2.04-SIR-days10-(0.48,70)-repeat3","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"70","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2953: {"name":"2.04-SIR-days10-(0.48,70)-repeat4","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"70","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2954: {"name":"2.04-SIR-days10-(0.48,80)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"80","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2955: {"name":"2.04-SIR-days10-(0.48,80)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"80","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2956: {"name":"2.04-SIR-days10-(0.48,80)-repeat3","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"80","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2957: {"name":"2.04-SIR-days10-(0.48,80)-repeat4","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"80","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2958: {"name":"2.04-SIR-days10-(0.48,90)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"90","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2959: {"name":"2.04-SIR-days10-(0.48,90)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"90","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2960: {"name":"2.04-SIR-days10-(0.48,90)-repeat3","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"90","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2961: {"name":"2.04-SIR-days10-(0.48,90)-repeat4","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"90","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2962: {"name":"2.04-SIR-days10-(0.48,100)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"100","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2963: {"name":"2.04-SIR-days10-(0.48,100)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"100","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
# 2964: {"name":"2.04-SIR-days10-(0.48,100)-repeat3","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"100","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 2965: {"name":"2.04-SIR-days10-(0.48,100)-repeat4","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"100","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-01T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
