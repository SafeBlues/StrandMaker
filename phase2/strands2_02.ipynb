# %% [markdown]
# ## Strands for Phase 2, release 0.02 (2.02)
#
# 600 strands in total
#
# This release is identical to 2.01 but with a three week delay. It was motivated by the NZ lockdown of Aug 18, 2021.

# %%
strengthArray = [0.08, 0.16, 0.48]
radiusArray = [30, 35, 40, 45, 50, 60, 70, 80, 90, 100]
numRepeats_SIR_SEIR = 4; 
numRepeats_SI_SEI = 2;

# %%
function createRepeats(parentStrand::Dict{Symbol,String}, num)
    strands = Array{Dict{Symbol,String}}(undef,0)
    for s in strengthArray, r in radiusArray, n in 1:num
        strand = deepcopy(parentStrand)
        strand[:name] = strand[:name]*"-($s,$r)-repeat$n"
        strand[:strength] = "$s"
        strand[:radius] = "$r"
        push!(strands,strand)
    end
    strands
end;

# %%
baseStrand = Dict{Symbol,String}()
baseStrand[:seedTime] = "2021-08-18T21:00:00Z" #9am on Thursday morning Aug 19 (in Auckland)
baseStrand[:endTime] = "2021-11-04T20:00:00Z"#9pm in the evening of Nov 4 (in Auckland)
baseStrand[:minimumAppVersion] = "60";

# %%
### SEI epidemics
SEIstrand = deepcopy(baseStrand)
SEIstrand[:name] = "2.02-SEI"
SEIstrand[:seedingProbability] = "0.1"
SEIstrand[:incubationMean] = "172800" #default for two days incubation
SEIstrand[:incubationShape] = "3"
SEIstrand[:infectionMean] = "31536000" #365 days
SEIstrand[:infectiousPeriodShape] = "10000";
SEIstrand
# Out:
# Dict{Symbol, String} with 9 entries:
#   :infectionMean         => "31536000"
#   :endTime               => "2021-11-04T20:00:00Z"
#   :incubationShape       => "3"
#   :minimumAppVersion     => "60"
#   :name                  => "2.01-SEI"
#   :seedingProbability    => "0.1"
#   :infectiousPeriodShape => "10000"
#   :seedTime              => "2021-08-18T21:00:00Z"
#   :incubationMean        => "172800"

# %%
##SI
SIstrand = deepcopy(SEIstrand)
SIstrand[:name] = "2.02-SI"
SIstrand[:incubationMean] = "1" #1 second incubation
SIstrand[:incubationShape] = "10000"
SIstrand
# Out:
# Dict{Symbol, String} with 9 entries:
#   :infectionMean         => "31536000"
#   :endTime               => "2021-11-04T20:00:00Z"
#   :incubationShape       => "10000"
#   :minimumAppVersion     => "60"
#   :name                  => "2.01-SI"
#   :seedingProbability    => "0.1"
#   :infectiousPeriodShape => "10000"
#   :seedTime              => "2021-08-18T21:00:00Z"
#   :incubationMean        => "1"

# %%
#The base strand for the SEIR epidemics
SEIRstrand = deepcopy(baseStrand)
SEIRstrand[:name] = "2.01-SEIR"
SEIRstrand[:seedingProbability] = "0.1"
SEIRstrand[:incubationMean] = "172800" 
SEIRstrand[:incubationShape] = "3"
SEIRstrand[:infectionMean] = "432000" #5 days should vary
SEIRstrand[:infectiousPeriodShape] = "3";
SEIRstrand
# Out:
# Dict{Symbol, String} with 9 entries:
#   :infectionMean         => "432000"
#   :endTime               => "2021-11-04T20:00:00Z"
#   :incubationShape       => "3"
#   :minimumAppVersion     => "60"
#   :name                  => "2.01-SEIR"
#   :seedingProbability    => "0.1"
#   :infectiousPeriodShape => "3"
#   :seedTime              => "2021-08-18T21:00:00Z"
#   :incubationMean        => "172800"

# %%
##SIR base strand
SIRstrand = deepcopy(SEIRstrand)
SIRstrand[:name] = "2.01-SIR"
SIRstrand[:incubationMean] = "1" #1 second incubation
SIRstrand[:incubationShape] = "10000"
SIRstrand
# Out:
# Dict{Symbol, String} with 9 entries:
#   :infectionMean         => "432000"
#   :endTime               => "2021-11-04T20:00:00Z"
#   :incubationShape       => "10000"
#   :minimumAppVersion     => "60"
#   :name                  => "2.01-SIR"
#   :seedingProbability    => "0.1"
#   :infectiousPeriodShape => "3"
#   :seedTime              => "2021-08-18T21:00:00Z"
#   :incubationMean        => "1"

# %%
SEIRstrandShortDuration = deepcopy(SEIRstrand)
SEIRstrandShortDuration[:name] = SEIRstrandShortDuration[:name]*"-days5";
SEIRstrandShortDuration
# Out:
# Dict{Symbol, String} with 9 entries:
#   :infectionMean         => "432000"
#   :endTime               => "2021-11-04T20:00:00Z"
#   :incubationShape       => "3"
#   :minimumAppVersion     => "60"
#   :name                  => "2.01-SEIR-days5"
#   :seedingProbability    => "0.1"
#   :infectiousPeriodShape => "3"
#   :seedTime              => "2021-08-18T21:00:00Z"
#   :incubationMean        => "172800"

# %%
SEIRstrandLongDuration = deepcopy(SEIRstrand)
SEIRstrandLongDuration[:infectionMean] = "864000" #10 days 
SEIRstrandLongDuration[:name] = SEIRstrandLongDuration[:name]*"-days10";
SEIRstrandLongDuration
# Out:
# Dict{Symbol, String} with 9 entries:
#   :infectionMean         => "864000"
#   :endTime               => "2021-11-04T20:00:00Z"
#   :incubationShape       => "3"
#   :minimumAppVersion     => "60"
#   :name                  => "2.01-SEIR-days10"
#   :seedingProbability    => "0.1"
#   :infectiousPeriodShape => "3"
#   :seedTime              => "2021-08-18T21:00:00Z"
#   :incubationMean        => "172800"

# %%
SIRstrandShortDuration = deepcopy(SIRstrand)
SIRstrandShortDuration[:name] = SIRstrandShortDuration[:name]*"-days5";
SIRstrandShortDuration
# Out:
# Dict{Symbol, String} with 9 entries:
#   :infectionMean         => "432000"
#   :endTime               => "2021-11-04T20:00:00Z"
#   :incubationShape       => "10000"
#   :minimumAppVersion     => "60"
#   :name                  => "2.01-SIR-days5"
#   :seedingProbability    => "0.1"
#   :infectiousPeriodShape => "3"
#   :seedTime              => "2021-08-18T21:00:00Z"
#   :incubationMean        => "1"

# %%
SIRstrandLongDuration = deepcopy(SIRstrand)
SIRstrandLongDuration[:infectionMean] = "864000" #10 days 
SIRstrandLongDuration[:name] = SIRstrandLongDuration[:name]*"-days10";
SIRstrandLongDuration
# Out:
# Dict{Symbol, String} with 9 entries:
#   :infectionMean         => "864000"
#   :endTime               => "2021-11-04T20:00:00Z"
#   :incubationShape       => "10000"
#   :minimumAppVersion     => "60"
#   :name                  => "2.01-SIR-days10"
#   :seedingProbability    => "0.1"
#   :infectiousPeriodShape => "3"
#   :seedTime              => "2021-08-18T21:00:00Z"
#   :incubationMean        => "1"

# %%
#An array that will hold all strands
strands = Array{Dict{Symbol,String}}(undef,0)
append!(strands, createRepeats(SIstrand, numRepeats_SI_SEI))
append!(strands, createRepeats(SEIstrand, numRepeats_SI_SEI))
append!(strands, createRepeats(SEIRstrandShortDuration, numRepeats_SIR_SEIR))
append!(strands, createRepeats(SEIRstrandLongDuration, numRepeats_SIR_SEIR))
append!(strands, createRepeats(SIRstrandShortDuration, numRepeats_SIR_SEIR))
append!(strands, createRepeats(SIRstrandLongDuration, numRepeats_SIR_SEIR));

# %%
length(strands)
# Out:
# 600

# %%
function strandJSON(sd::Dict{Symbol,String})
    str = """
        {\"name\":\"$(sd[:name])\",
         \"seedingProbability\":\"$(sd[:seedingProbability])\",
         \"infectionProbabilityMapP\":\"$(sd[:strength])\",
         \"infectionProbabilityMapK\":\"$(sd[:radius])\",
         \"infectionProbabilityMapL\":\"1000000\",
         \"incubationPeriodMeanSec\":\"$(sd[:incubationMean])\",
         \"incubationPeriodShape\":\"$(sd[:incubationShape])\",
         \"infectiousPeriodMeanSec\":\"$(sd[:infectionMean])\",
         \"infectiousPeriodShape\":\"$(sd[:infectiousPeriodShape])\",
         \"startTime\":\"$(sd[:seedTime])\",
         \"endTime\":\"$(sd[:endTime])\",
         \"minimumAppVersion\":\"$(sd[:minimumAppVersion])\"}
    """
    join(map(x -> isspace(str[x]) ? "" : str[x], 1:length(str))) #how the $%@$% to remove white space in Julia strings?
end

strandStrings = strandJSON.(strands)
if length(filter(x->x=="strands2_02.txt",map(abspath, readdir())))!=0
    rm("strands2_02.txt") #remove the text file in the working directory if exists
end
touch("strands2_02.txt") #create the text file in the working directory
open("strands2_02.txt","w") do file 
    newID = 1165 #last strand in system
    for s in strandStrings
        newID +=1
        write(file,"$newID: $s\n")
        println("$newID: $s\n")
    end
end
# Out:
# 1166: {"name":"2.01-SI-(0.08,30)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"30","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1167: {"name":"2.01-SI-(0.08,30)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"30","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1168: {"name":"2.01-SI-(0.08,35)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"35","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1169: {"name":"2.01-SI-(0.08,35)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"35","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1170: {"name":"2.01-SI-(0.08,40)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"40","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1171: {"name":"2.01-SI-(0.08,40)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"40","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1172: {"name":"2.01-SI-(0.08,45)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"45","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1173: {"name":"2.01-SI-(0.08,45)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"45","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1174: {"name":"2.01-SI-(0.08,50)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"50","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1175: {"name":"2.01-SI-(0.08,50)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"50","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1176: {"name":"2.01-SI-(0.08,60)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"60","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1177: {"name":"2.01-SI-(0.08,60)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"60","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1178: {"name":"2.01-SI-(0.08,70)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"70","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1179: {"name":"2.01-SI-(0.08,70)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"70","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1180: {"name":"2.01-SI-(0.08,80)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"80","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1181: {"name":"2.01-SI-(0.08,80)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"80","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1182: {"name":"2.01-SI-(0.08,90)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"90","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1183: {"name":"2.01-SI-(0.08,90)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"90","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1184: {"name":"2.01-SI-(0.08,100)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"100","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1185: {"name":"2.01-SI-(0.08,100)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"100","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1186: {"name":"2.01-SI-(0.16,30)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"30","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1187: {"name":"2.01-SI-(0.16,30)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"30","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1188: {"name":"2.01-SI-(0.16,35)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"35","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1189: {"name":"2.01-SI-(0.16,35)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"35","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1190: {"name":"2.01-SI-(0.16,40)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"40","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1191: {"name":"2.01-SI-(0.16,40)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"40","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
# 1192: {"name":"2.01-SI-(0.16,45)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"45","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1193: {"name":"2.01-SI-(0.16,45)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"45","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1194: {"name":"2.01-SI-(0.16,50)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"50","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1195: {"name":"2.01-SI-(0.16,50)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"50","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1196: {"name":"2.01-SI-(0.16,60)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"60","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1197: {"name":"2.01-SI-(0.16,60)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"60","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1198: {"name":"2.01-SI-(0.16,70)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"70","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1199: {"name":"2.01-SI-(0.16,70)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"70","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1200: {"name":"2.01-SI-(0.16,80)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"80","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1201: {"name":"2.01-SI-(0.16,80)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"80","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1202: {"name":"2.01-SI-(0.16,90)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"90","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1203: {"name":"2.01-SI-(0.16,90)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"90","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1204: {"name":"2.01-SI-(0.16,100)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"100","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1205: {"name":"2.01-SI-(0.16,100)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"100","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1206: {"name":"2.01-SI-(0.48,30)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"30","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1207: {"name":"2.01-SI-(0.48,30)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"30","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1208: {"name":"2.01-SI-(0.48,35)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"35","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1209: {"name":"2.01-SI-(0.48,35)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"35","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1210: {"name":"2.01-SI-(0.48,40)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"40","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1211: {"name":"2.01-SI-(0.48,40)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"40","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1212: {"name":"2.01-SI-(0.48,45)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"45","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1213: {"name":"2.01-SI-(0.48,45)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"45","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1214: {"name":"2.01-SI-(0.48,50)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"50","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1215: {"name":"2.01-SI-(0.48,50)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"50","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1216: {"name":"2.01-SI-(0.48,60)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"60","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1217: {"name":"2.01-SI-(0.48,60)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"60","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
# 1218: {"name":"2.01-SI-(0.48,70)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"70","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1219: {"name":"2.01-SI-(0.48,70)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"70","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1220: {"name":"2.01-SI-(0.48,80)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"80","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1221: {"name":"2.01-SI-(0.48,80)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"80","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1222: {"name":"2.01-SI-(0.48,90)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"90","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1223: {"name":"2.01-SI-(0.48,90)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"90","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1224: {"name":"2.01-SI-(0.48,100)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"100","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1225: {"name":"2.01-SI-(0.48,100)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"100","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1226: {"name":"2.01-SEI-(0.08,30)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"30","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1227: {"name":"2.01-SEI-(0.08,30)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"30","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1228: {"name":"2.01-SEI-(0.08,35)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"35","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1229: {"name":"2.01-SEI-(0.08,35)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"35","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1230: {"name":"2.01-SEI-(0.08,40)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"40","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1231: {"name":"2.01-SEI-(0.08,40)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"40","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1232: {"name":"2.01-SEI-(0.08,45)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"45","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1233: {"name":"2.01-SEI-(0.08,45)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"45","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1234: {"name":"2.01-SEI-(0.08,50)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"50","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1235: {"name":"2.01-SEI-(0.08,50)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"50","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1236: {"name":"2.01-SEI-(0.08,60)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"60","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1237: {"name":"2.01-SEI-(0.08,60)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"60","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1238: {"name":"2.01-SEI-(0.08,70)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"70","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1239: {"name":"2.01-SEI-(0.08,70)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"70","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1240: {"name":"2.01-SEI-(0.08,80)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"80","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1241: {"name":"2.01-SEI-(0.08,80)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"80","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1242: {"name":"2.01-SEI-(0.08,90)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"90","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1243: {"name":"2.01-SEI-(0.08,90)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"90","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
# 1244: {"name":"2.01-SEI-(0.08,100)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"100","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1245: {"name":"2.01-SEI-(0.08,100)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"100","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1246: {"name":"2.01-SEI-(0.16,30)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"30","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1247: {"name":"2.01-SEI-(0.16,30)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"30","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1248: {"name":"2.01-SEI-(0.16,35)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"35","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1249: {"name":"2.01-SEI-(0.16,35)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"35","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1250: {"name":"2.01-SEI-(0.16,40)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"40","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1251: {"name":"2.01-SEI-(0.16,40)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"40","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1252: {"name":"2.01-SEI-(0.16,45)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"45","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1253: {"name":"2.01-SEI-(0.16,45)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"45","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1254: {"name":"2.01-SEI-(0.16,50)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"50","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1255: {"name":"2.01-SEI-(0.16,50)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"50","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1256: {"name":"2.01-SEI-(0.16,60)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"60","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1257: {"name":"2.01-SEI-(0.16,60)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"60","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1258: {"name":"2.01-SEI-(0.16,70)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"70","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1259: {"name":"2.01-SEI-(0.16,70)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"70","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1260: {"name":"2.01-SEI-(0.16,80)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"80","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1261: {"name":"2.01-SEI-(0.16,80)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"80","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1262: {"name":"2.01-SEI-(0.16,90)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"90","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1263: {"name":"2.01-SEI-(0.16,90)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"90","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1264: {"name":"2.01-SEI-(0.16,100)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"100","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1265: {"name":"2.01-SEI-(0.16,100)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"100","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1266: {"name":"2.01-SEI-(0.48,30)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"30","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1267: {"name":"2.01-SEI-(0.48,30)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"30","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1268: {"name":"2.01-SEI-(0.48,35)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"35","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1269: {"name":"2.01-SEI-(0.48,35)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"35","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
# 1270: {"name":"2.01-SEI-(0.48,40)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"40","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1271: {"name":"2.01-SEI-(0.48,40)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"40","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1272: {"name":"2.01-SEI-(0.48,45)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"45","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1273: {"name":"2.01-SEI-(0.48,45)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"45","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1274: {"name":"2.01-SEI-(0.48,50)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"50","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1275: {"name":"2.01-SEI-(0.48,50)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"50","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1276: {"name":"2.01-SEI-(0.48,60)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"60","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1277: {"name":"2.01-SEI-(0.48,60)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"60","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1278: {"name":"2.01-SEI-(0.48,70)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"70","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1279: {"name":"2.01-SEI-(0.48,70)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"70","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1280: {"name":"2.01-SEI-(0.48,80)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"80","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1281: {"name":"2.01-SEI-(0.48,80)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"80","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1282: {"name":"2.01-SEI-(0.48,90)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"90","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1283: {"name":"2.01-SEI-(0.48,90)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"90","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1284: {"name":"2.01-SEI-(0.48,100)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"100","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1285: {"name":"2.01-SEI-(0.48,100)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"100","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# ...
#
# 1727: {"name":"2.01-SIR-days10-(0.48,30)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"30","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1728: {"name":"2.01-SIR-days10-(0.48,30)-repeat3","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"30","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1729: {"name":"2.01-SIR-days10-(0.48,30)-repeat4","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"30","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1730: {"name":"2.01-SIR-days10-(0.48,35)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"35","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1731: {"name":"2.01-SIR-days10-(0.48,35)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"35","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1732: {"name":"2.01-SIR-days10-(0.48,35)-repeat3","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"35","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1733: {"name":"2.01-SIR-days10-(0.48,35)-repeat4","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"35","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1734: {"name":"2.01-SIR-days10-(0.48,40)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"40","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1735: {"name":"2.01-SIR-days10-(0.48,40)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"40","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1736: {"name":"2.01-SIR-days10-(0.48,40)-repeat3","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"40","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1737: {"name":"2.01-SIR-days10-(0.48,40)-repeat4","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"40","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
# 1738: {"name":"2.01-SIR-days10-(0.48,45)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"45","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1739: {"name":"2.01-SIR-days10-(0.48,45)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"45","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1740: {"name":"2.01-SIR-days10-(0.48,45)-repeat3","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"45","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1741: {"name":"2.01-SIR-days10-(0.48,45)-repeat4","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"45","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1742: {"name":"2.01-SIR-days10-(0.48,50)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"50","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1743: {"name":"2.01-SIR-days10-(0.48,50)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"50","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1744: {"name":"2.01-SIR-days10-(0.48,50)-repeat3","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"50","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1745: {"name":"2.01-SIR-days10-(0.48,50)-repeat4","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"50","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1746: {"name":"2.01-SIR-days10-(0.48,60)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"60","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1747: {"name":"2.01-SIR-days10-(0.48,60)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"60","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1748: {"name":"2.01-SIR-days10-(0.48,60)-repeat3","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"60","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1749: {"name":"2.01-SIR-days10-(0.48,60)-repeat4","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"60","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1750: {"name":"2.01-SIR-days10-(0.48,70)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"70","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1751: {"name":"2.01-SIR-days10-(0.48,70)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"70","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1752: {"name":"2.01-SIR-days10-(0.48,70)-repeat3","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"70","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1753: {"name":"2.01-SIR-days10-(0.48,70)-repeat4","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"70","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1754: {"name":"2.01-SIR-days10-(0.48,80)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"80","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1755: {"name":"2.01-SIR-days10-(0.48,80)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"80","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1756: {"name":"2.01-SIR-days10-(0.48,80)-repeat3","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"80","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1757: {"name":"2.01-SIR-days10-(0.48,80)-repeat4","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"80","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1758: {"name":"2.01-SIR-days10-(0.48,90)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"90","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1759: {"name":"2.01-SIR-days10-(0.48,90)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"90","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1760: {"name":"2.01-SIR-days10-(0.48,90)-repeat3","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"90","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1761: {"name":"2.01-SIR-days10-(0.48,90)-repeat4","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"90","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1762: {"name":"2.01-SIR-days10-(0.48,100)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"100","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1763: {"name":"2.01-SIR-days10-(0.48,100)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"100","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
# 1764: {"name":"2.01-SIR-days10-(0.48,100)-repeat3","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"100","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 1765: {"name":"2.01-SIR-days10-(0.48,100)-repeat4","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"100","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-08-18T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
