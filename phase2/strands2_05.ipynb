# %% [markdown]
# ## Strands for Phase 2, release 0.05 (2.05)
#
# 600 strands in total
#
# This release is identical to 2.04 but with a one week delay.

# %%
strengthArray = [0.08, 0.16, 0.48]
radiusArray = [30, 35, 40, 45, 50, 60, 70, 80, 90, 100]
numRepeats_SIR_SEIR = 4;
numRepeats_SI_SEI = 2;

# %%
function createRepeats(parentStrand::Dict{Symbol,String}, num)
    strands = Array{Dict{Symbol,String}}(undef,0)
    for s in strengthArray, r in radiusArray, n in 1:num
        strand = deepcopy(parentStrand)
        strand[:name] = strand[:name]*"-($s,$r)-repeat$n"
        strand[:strength] = "$s"
        strand[:radius] = "$r"
        push!(strands,strand)
    end
    strands
end;

# %%
baseStrand = Dict{Symbol,String}()
baseStrand[:seedTime] = "2021-09-08T21:00:00Z" #9am on Thursday morning Sep 02 (in Auckland)
baseStrand[:endTime] = "2021-11-04T20:00:00Z"#9pm in the evening of Nov 4 (in Auckland)
baseStrand[:minimumAppVersion] = "60";

# %%
### SEI epidemics
SEIstrand = deepcopy(baseStrand)
SEIstrand[:name] = "2.05-SEI"
SEIstrand[:seedingProbability] = "0.1"
SEIstrand[:incubationMean] = "172800" #default for two days incubation
SEIstrand[:incubationShape] = "3"
SEIstrand[:infectionMean] = "31536000" #365 days
SEIstrand[:infectiousPeriodShape] = "10000";
SEIstrand
# Out:
# Dict{Symbol, String} with 9 entries:
#   :infectionMean         => "31536000"
#   :endTime               => "2021-11-04T20:00:00Z"
#   :incubationShape       => "3"
#   :minimumAppVersion     => "60"
#   :name                  => "2.05-SEI"
#   :seedingProbability    => "0.1"
#   :infectiousPeriodShape => "10000"
#   :seedTime              => "2021-09-08T21:00:00Z"
#   :incubationMean        => "172800"

# %%
##SI
SIstrand = deepcopy(SEIstrand)
SIstrand[:name] = "2.05-SI"
SIstrand[:incubationMean] = "1" #1 second incubation
SIstrand[:incubationShape] = "10000"
SIstrand
# Out:
# Dict{Symbol, String} with 9 entries:
#   :infectionMean         => "31536000"
#   :endTime               => "2021-11-04T20:00:00Z"
#   :incubationShape       => "10000"
#   :minimumAppVersion     => "60"
#   :name                  => "2.05-SI"
#   :seedingProbability    => "0.1"
#   :infectiousPeriodShape => "10000"
#   :seedTime              => "2021-09-08T21:00:00Z"
#   :incubationMean        => "1"

# %%
#The base strand for the SEIR epidemics
SEIRstrand = deepcopy(baseStrand)
SEIRstrand[:name] = "2.05-SEIR"
SEIRstrand[:seedingProbability] = "0.1"
SEIRstrand[:incubationMean] = "172800" 
SEIRstrand[:incubationShape] = "3"
SEIRstrand[:infectionMean] = "432000" #5 days should vary
SEIRstrand[:infectiousPeriodShape] = "3";
SEIRstrand
# Out:
# Dict{Symbol, String} with 9 entries:
#   :infectionMean         => "432000"
#   :endTime               => "2021-11-04T20:00:00Z"
#   :incubationShape       => "3"
#   :minimumAppVersion     => "60"
#   :name                  => "2.05-SEIR"
#   :seedingProbability    => "0.1"
#   :infectiousPeriodShape => "3"
#   :seedTime              => "2021-09-08T21:00:00Z"
#   :incubationMean        => "172800"

# %%
##SIR base strand
SIRstrand = deepcopy(SEIRstrand)
SIRstrand[:name] = "2.05-SIR"
SIRstrand[:incubationMean] = "1" #1 second incubation
SIRstrand[:incubationShape] = "10000"
SIRstrand
# Out:
# Dict{Symbol, String} with 9 entries:
#   :infectionMean         => "432000"
#   :endTime               => "2021-11-04T20:00:00Z"
#   :incubationShape       => "10000"
#   :minimumAppVersion     => "60"
#   :name                  => "2.05-SIR"
#   :seedingProbability    => "0.1"
#   :infectiousPeriodShape => "3"
#   :seedTime              => "2021-09-08T21:00:00Z"
#   :incubationMean        => "1"

# %%
SEIRstrandShortDuration = deepcopy(SEIRstrand)
SEIRstrandShortDuration[:name] = SEIRstrandShortDuration[:name]*"-days5";
SEIRstrandShortDuration
# Out:
# Dict{Symbol, String} with 9 entries:
#   :infectionMean         => "432000"
#   :endTime               => "2021-11-04T20:00:00Z"
#   :incubationShape       => "3"
#   :minimumAppVersion     => "60"
#   :name                  => "2.05-SEIR-days5"
#   :seedingProbability    => "0.1"
#   :infectiousPeriodShape => "3"
#   :seedTime              => "2021-09-08T21:00:00Z"
#   :incubationMean        => "172800"

# %%
SEIRstrandLongDuration = deepcopy(SEIRstrand)
SEIRstrandLongDuration[:infectionMean] = "864000" #10 days 
SEIRstrandLongDuration[:name] = SEIRstrandLongDuration[:name]*"-days10";
SEIRstrandLongDuration
# Out:
# Dict{Symbol, String} with 9 entries:
#   :infectionMean         => "864000"
#   :endTime               => "2021-11-04T20:00:00Z"
#   :incubationShape       => "3"
#   :minimumAppVersion     => "60"
#   :name                  => "2.05-SEIR-days10"
#   :seedingProbability    => "0.1"
#   :infectiousPeriodShape => "3"
#   :seedTime              => "2021-09-08T21:00:00Z"
#   :incubationMean        => "172800"

# %%
SIRstrandShortDuration = deepcopy(SIRstrand)
SIRstrandShortDuration[:name] = SIRstrandShortDuration[:name]*"-days5";
SIRstrandShortDuration
# Out:
# Dict{Symbol, String} with 9 entries:
#   :infectionMean         => "432000"
#   :endTime               => "2021-11-04T20:00:00Z"
#   :incubationShape       => "10000"
#   :minimumAppVersion     => "60"
#   :name                  => "2.05-SIR-days5"
#   :seedingProbability    => "0.1"
#   :infectiousPeriodShape => "3"
#   :seedTime              => "2021-09-08T21:00:00Z"
#   :incubationMean        => "1"

# %%
SIRstrandLongDuration = deepcopy(SIRstrand)
SIRstrandLongDuration[:infectionMean] = "864000" #10 days 
SIRstrandLongDuration[:name] = SIRstrandLongDuration[:name]*"-days10";
SIRstrandLongDuration
# Out:
# Dict{Symbol, String} with 9 entries:
#   :infectionMean         => "864000"
#   :endTime               => "2021-11-04T20:00:00Z"
#   :incubationShape       => "10000"
#   :minimumAppVersion     => "60"
#   :name                  => "2.05-SIR-days10"
#   :seedingProbability    => "0.1"
#   :infectiousPeriodShape => "3"
#   :seedTime              => "2021-09-08T21:00:00Z"
#   :incubationMean        => "1"

# %%
#An array that will hold all strands
strands = Array{Dict{Symbol,String}}(undef,0)
append!(strands, createRepeats(SIstrand, numRepeats_SI_SEI))
append!(strands, createRepeats(SEIstrand, numRepeats_SI_SEI))
append!(strands, createRepeats(SEIRstrandShortDuration, numRepeats_SIR_SEIR))
append!(strands, createRepeats(SEIRstrandLongDuration, numRepeats_SIR_SEIR))
append!(strands, createRepeats(SIRstrandShortDuration, numRepeats_SIR_SEIR))
append!(strands, createRepeats(SIRstrandLongDuration, numRepeats_SIR_SEIR));

# %%
length(strands)
# Out:
# 600

# %%
function strandJSON(sd::Dict{Symbol,String})
    str = """
        {\"name\":\"$(sd[:name])\",
         \"seedingProbability\":\"$(sd[:seedingProbability])\",
         \"infectionProbabilityMapP\":\"$(sd[:strength])\",
         \"infectionProbabilityMapK\":\"$(sd[:radius])\",
         \"infectionProbabilityMapL\":\"1000000\",
         \"incubationPeriodMeanSec\":\"$(sd[:incubationMean])\",
         \"incubationPeriodShape\":\"$(sd[:incubationShape])\",
         \"infectiousPeriodMeanSec\":\"$(sd[:infectionMean])\",
         \"infectiousPeriodShape\":\"$(sd[:infectiousPeriodShape])\",
         \"startTime\":\"$(sd[:seedTime])\",
         \"endTime\":\"$(sd[:endTime])\",
         \"minimumAppVersion\":\"$(sd[:minimumAppVersion])\"}
    """
    join(map(x -> isspace(str[x]) ? "" : str[x], 1:length(str))) #how the $%@$% to remove white space in Julia strings?
end

strandStrings = strandJSON.(strands)
if length(filter(x->x=="strands2_05.txt",map(abspath, readdir())))!=0
    rm("strands2_05.txt") #remove the text file in the working directory if exists
end
touch("strands2_05.txt") #create the text file in the working directory
open("strands2_05.txt","w") do file 
    newID = 3070 #last strand in system
    for s in strandStrings
        newID +=1
        write(file,"$newID: $s\n")
        println("$newID: $s\n")
    end
end
# Out:
# 3071: {"name":"2.05-SI-(0.08,30)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"30","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3072: {"name":"2.05-SI-(0.08,30)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"30","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3073: {"name":"2.05-SI-(0.08,35)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"35","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3074: {"name":"2.05-SI-(0.08,35)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"35","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3075: {"name":"2.05-SI-(0.08,40)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"40","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3076: {"name":"2.05-SI-(0.08,40)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"40","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3077: {"name":"2.05-SI-(0.08,45)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"45","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3078: {"name":"2.05-SI-(0.08,45)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"45","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3079: {"name":"2.05-SI-(0.08,50)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"50","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3080: {"name":"2.05-SI-(0.08,50)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"50","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3081: {"name":"2.05-SI-(0.08,60)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"60","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3082: {"name":"2.05-SI-(0.08,60)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"60","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3083: {"name":"2.05-SI-(0.08,70)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"70","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3084: {"name":"2.05-SI-(0.08,70)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"70","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3085: {"name":"2.05-SI-(0.08,80)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"80","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3086: {"name":"2.05-SI-(0.08,80)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"80","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3087: {"name":"2.05-SI-(0.08,90)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"90","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3088: {"name":"2.05-SI-(0.08,90)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"90","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3089: {"name":"2.05-SI-(0.08,100)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"100","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3090: {"name":"2.05-SI-(0.08,100)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"100","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3091: {"name":"2.05-SI-(0.16,30)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"30","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3092: {"name":"2.05-SI-(0.16,30)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"30","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3093: {"name":"2.05-SI-(0.16,35)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"35","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3094: {"name":"2.05-SI-(0.16,35)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"35","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3095: {"name":"2.05-SI-(0.16,40)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"40","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3096: {"name":"2.05-SI-(0.16,40)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"40","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
# 3097: {"name":"2.05-SI-(0.16,45)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"45","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3098: {"name":"2.05-SI-(0.16,45)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"45","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3099: {"name":"2.05-SI-(0.16,50)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"50","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3100: {"name":"2.05-SI-(0.16,50)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"50","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3101: {"name":"2.05-SI-(0.16,60)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"60","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3102: {"name":"2.05-SI-(0.16,60)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"60","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3103: {"name":"2.05-SI-(0.16,70)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"70","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3104: {"name":"2.05-SI-(0.16,70)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"70","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3105: {"name":"2.05-SI-(0.16,80)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"80","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3106: {"name":"2.05-SI-(0.16,80)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"80","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3107: {"name":"2.05-SI-(0.16,90)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"90","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3108: {"name":"2.05-SI-(0.16,90)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"90","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3109: {"name":"2.05-SI-(0.16,100)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"100","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3110: {"name":"2.05-SI-(0.16,100)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"100","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3111: {"name":"2.05-SI-(0.48,30)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"30","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3112: {"name":"2.05-SI-(0.48,30)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"30","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3113: {"name":"2.05-SI-(0.48,35)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"35","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3114: {"name":"2.05-SI-(0.48,35)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"35","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3115: {"name":"2.05-SI-(0.48,40)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"40","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3116: {"name":"2.05-SI-(0.48,40)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"40","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3117: {"name":"2.05-SI-(0.48,45)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"45","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3118: {"name":"2.05-SI-(0.48,45)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"45","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3119: {"name":"2.05-SI-(0.48,50)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"50","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3120: {"name":"2.05-SI-(0.48,50)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"50","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3121: {"name":"2.05-SI-(0.48,60)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"60","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3122: {"name":"2.05-SI-(0.48,60)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"60","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
# 3123: {"name":"2.05-SI-(0.48,70)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"70","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3124: {"name":"2.05-SI-(0.48,70)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"70","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3125: {"name":"2.05-SI-(0.48,80)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"80","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3126: {"name":"2.05-SI-(0.48,80)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"80","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3127: {"name":"2.05-SI-(0.48,90)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"90","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3128: {"name":"2.05-SI-(0.48,90)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"90","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3129: {"name":"2.05-SI-(0.48,100)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"100","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3130: {"name":"2.05-SI-(0.48,100)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"100","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3131: {"name":"2.05-SEI-(0.08,30)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"30","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3132: {"name":"2.05-SEI-(0.08,30)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"30","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3133: {"name":"2.05-SEI-(0.08,35)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"35","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3134: {"name":"2.05-SEI-(0.08,35)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"35","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3135: {"name":"2.05-SEI-(0.08,40)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"40","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3136: {"name":"2.05-SEI-(0.08,40)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"40","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3137: {"name":"2.05-SEI-(0.08,45)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"45","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3138: {"name":"2.05-SEI-(0.08,45)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"45","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3139: {"name":"2.05-SEI-(0.08,50)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"50","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3140: {"name":"2.05-SEI-(0.08,50)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"50","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3141: {"name":"2.05-SEI-(0.08,60)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"60","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3142: {"name":"2.05-SEI-(0.08,60)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"60","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3143: {"name":"2.05-SEI-(0.08,70)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"70","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3144: {"name":"2.05-SEI-(0.08,70)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"70","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3145: {"name":"2.05-SEI-(0.08,80)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"80","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3146: {"name":"2.05-SEI-(0.08,80)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"80","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3147: {"name":"2.05-SEI-(0.08,90)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"90","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3148: {"name":"2.05-SEI-(0.08,90)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"90","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
# 3149: {"name":"2.05-SEI-(0.08,100)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"100","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3150: {"name":"2.05-SEI-(0.08,100)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"100","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3151: {"name":"2.05-SEI-(0.16,30)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"30","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3152: {"name":"2.05-SEI-(0.16,30)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"30","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3153: {"name":"2.05-SEI-(0.16,35)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"35","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3154: {"name":"2.05-SEI-(0.16,35)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"35","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3155: {"name":"2.05-SEI-(0.16,40)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"40","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3156: {"name":"2.05-SEI-(0.16,40)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"40","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3157: {"name":"2.05-SEI-(0.16,45)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"45","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3158: {"name":"2.05-SEI-(0.16,45)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"45","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3159: {"name":"2.05-SEI-(0.16,50)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"50","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3160: {"name":"2.05-SEI-(0.16,50)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"50","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3161: {"name":"2.05-SEI-(0.16,60)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"60","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3162: {"name":"2.05-SEI-(0.16,60)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"60","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3163: {"name":"2.05-SEI-(0.16,70)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"70","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3164: {"name":"2.05-SEI-(0.16,70)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"70","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3165: {"name":"2.05-SEI-(0.16,80)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"80","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3166: {"name":"2.05-SEI-(0.16,80)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"80","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3167: {"name":"2.05-SEI-(0.16,90)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"90","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3168: {"name":"2.05-SEI-(0.16,90)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"90","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3169: {"name":"2.05-SEI-(0.16,100)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"100","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3170: {"name":"2.05-SEI-(0.16,100)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"100","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3171: {"name":"2.05-SEI-(0.48,30)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"30","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3172: {"name":"2.05-SEI-(0.48,30)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"30","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3173: {"name":"2.05-SEI-(0.48,35)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"35","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3174: {"name":"2.05-SEI-(0.48,35)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"35","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
# 3175: {"name":"2.05-SEI-(0.48,40)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"40","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3176: {"name":"2.05-SEI-(0.48,40)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"40","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3177: {"name":"2.05-SEI-(0.48,45)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"45","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3178: {"name":"2.05-SEI-(0.48,45)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"45","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3179: {"name":"2.05-SEI-(0.48,50)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"50","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3180: {"name":"2.05-SEI-(0.48,50)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"50","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3181: {"name":"2.05-SEI-(0.48,60)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"60","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3182: {"name":"2.05-SEI-(0.48,60)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"60","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3183: {"name":"2.05-SEI-(0.48,70)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"70","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3184: {"name":"2.05-SEI-(0.48,70)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"70","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3185: {"name":"2.05-SEI-(0.48,80)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"80","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3186: {"name":"2.05-SEI-(0.48,80)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"80","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3187: {"name":"2.05-SEI-(0.48,90)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"90","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3188: {"name":"2.05-SEI-(0.48,90)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"90","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3189: {"name":"2.05-SEI-(0.48,100)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"100","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3190: {"name":"2.05-SEI-(0.48,100)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"100","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# ...
#
# 3632: {"name":"2.05-SIR-days10-(0.48,30)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"30","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3633: {"name":"2.05-SIR-days10-(0.48,30)-repeat3","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"30","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3634: {"name":"2.05-SIR-days10-(0.48,30)-repeat4","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"30","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3635: {"name":"2.05-SIR-days10-(0.48,35)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"35","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3636: {"name":"2.05-SIR-days10-(0.48,35)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"35","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3637: {"name":"2.05-SIR-days10-(0.48,35)-repeat3","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"35","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3638: {"name":"2.05-SIR-days10-(0.48,35)-repeat4","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"35","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3639: {"name":"2.05-SIR-days10-(0.48,40)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"40","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3640: {"name":"2.05-SIR-days10-(0.48,40)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"40","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3641: {"name":"2.05-SIR-days10-(0.48,40)-repeat3","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"40","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3642: {"name":"2.05-SIR-days10-(0.48,40)-repeat4","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"40","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
# 3643: {"name":"2.05-SIR-days10-(0.48,45)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"45","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3644: {"name":"2.05-SIR-days10-(0.48,45)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"45","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3645: {"name":"2.05-SIR-days10-(0.48,45)-repeat3","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"45","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3646: {"name":"2.05-SIR-days10-(0.48,45)-repeat4","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"45","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3647: {"name":"2.05-SIR-days10-(0.48,50)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"50","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3648: {"name":"2.05-SIR-days10-(0.48,50)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"50","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3649: {"name":"2.05-SIR-days10-(0.48,50)-repeat3","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"50","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3650: {"name":"2.05-SIR-days10-(0.48,50)-repeat4","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"50","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3651: {"name":"2.05-SIR-days10-(0.48,60)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"60","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3652: {"name":"2.05-SIR-days10-(0.48,60)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"60","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3653: {"name":"2.05-SIR-days10-(0.48,60)-repeat3","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"60","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3654: {"name":"2.05-SIR-days10-(0.48,60)-repeat4","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"60","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3655: {"name":"2.05-SIR-days10-(0.48,70)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"70","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3656: {"name":"2.05-SIR-days10-(0.48,70)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"70","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3657: {"name":"2.05-SIR-days10-(0.48,70)-repeat3","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"70","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3658: {"name":"2.05-SIR-days10-(0.48,70)-repeat4","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"70","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3659: {"name":"2.05-SIR-days10-(0.48,80)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"80","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3660: {"name":"2.05-SIR-days10-(0.48,80)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"80","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3661: {"name":"2.05-SIR-days10-(0.48,80)-repeat3","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"80","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3662: {"name":"2.05-SIR-days10-(0.48,80)-repeat4","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"80","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3663: {"name":"2.05-SIR-days10-(0.48,90)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"90","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3664: {"name":"2.05-SIR-days10-(0.48,90)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"90","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3665: {"name":"2.05-SIR-days10-(0.48,90)-repeat3","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"90","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3666: {"name":"2.05-SIR-days10-(0.48,90)-repeat4","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"90","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3667: {"name":"2.05-SIR-days10-(0.48,100)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"100","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3668: {"name":"2.05-SIR-days10-(0.48,100)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"100","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
# 3669: {"name":"2.05-SIR-days10-(0.48,100)-repeat3","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"100","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3670: {"name":"2.05-SIR-days10-(0.48,100)-repeat4","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"100","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-08T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
