# %% [markdown]
# ## Strands for Phase 2, release 0.06 (2.06)
#
# 600 strands in total
#
# This release is identical to 2.05 but with a one week delay.

# %%
strengthArray = [0.08, 0.16, 0.48]
radiusArray = [30, 35, 40, 45, 50, 60, 70, 80, 90, 100]
numRepeats_SIR_SEIR = 4;
numRepeats_SI_SEI = 2;

# %%
function createRepeats(parentStrand::Dict{Symbol,String}, num)
    strands = Array{Dict{Symbol,String}}(undef,0)
    for s in strengthArray, r in radiusArray, n in 1:num
        strand = deepcopy(parentStrand)
        strand[:name] = strand[:name]*"-($s,$r)-repeat$n"
        strand[:strength] = "$s"
        strand[:radius] = "$r"
        push!(strands,strand)
    end
    strands
end;

# %%
baseStrand = Dict{Symbol,String}()
baseStrand[:seedTime] = "2021-09-15T21:00:00Z" #9am on Thursday morning Sep 02 (in Auckland)
baseStrand[:endTime] = "2021-11-04T20:00:00Z"#9pm in the evening of Nov 4 (in Auckland)
baseStrand[:minimumAppVersion] = "60";

# %%
### SEI epidemics
SEIstrand = deepcopy(baseStrand)
SEIstrand[:name] = "2.06-SEI"
SEIstrand[:seedingProbability] = "0.1"
SEIstrand[:incubationMean] = "172800" #default for two days incubation
SEIstrand[:incubationShape] = "3"
SEIstrand[:infectionMean] = "31536000" #365 days
SEIstrand[:infectiousPeriodShape] = "10000";
SEIstrand
# Out:
# Dict{Symbol, String} with 9 entries:
#   :infectionMean         => "31536000"
#   :endTime               => "2021-11-04T20:00:00Z"
#   :incubationShape       => "3"
#   :minimumAppVersion     => "60"
#   :name                  => "2.06-SEI"
#   :seedingProbability    => "0.1"
#   :infectiousPeriodShape => "10000"
#   :seedTime              => "2021-09-15T21:00:00Z"
#   :incubationMean        => "172800"

# %%
##SI
SIstrand = deepcopy(SEIstrand)
SIstrand[:name] = "2.06-SI"
SIstrand[:incubationMean] = "1" #1 second incubation
SIstrand[:incubationShape] = "10000"
SIstrand
# Out:
# Dict{Symbol, String} with 9 entries:
#   :infectionMean         => "31536000"
#   :endTime               => "2021-11-04T20:00:00Z"
#   :incubationShape       => "10000"
#   :minimumAppVersion     => "60"
#   :name                  => "2.06-SI"
#   :seedingProbability    => "0.1"
#   :infectiousPeriodShape => "10000"
#   :seedTime              => "2021-09-15T21:00:00Z"
#   :incubationMean        => "1"

# %%
#The base strand for the SEIR epidemics
SEIRstrand = deepcopy(baseStrand)
SEIRstrand[:name] = "2.06-SEIR"
SEIRstrand[:seedingProbability] = "0.1"
SEIRstrand[:incubationMean] = "172800" 
SEIRstrand[:incubationShape] = "3"
SEIRstrand[:infectionMean] = "432000" #5 days should vary
SEIRstrand[:infectiousPeriodShape] = "3";
SEIRstrand
# Out:
# Dict{Symbol, String} with 9 entries:
#   :infectionMean         => "432000"
#   :endTime               => "2021-11-04T20:00:00Z"
#   :incubationShape       => "3"
#   :minimumAppVersion     => "60"
#   :name                  => "2.06-SEIR"
#   :seedingProbability    => "0.1"
#   :infectiousPeriodShape => "3"
#   :seedTime              => "2021-09-15T21:00:00Z"
#   :incubationMean        => "172800"

# %%
##SIR base strand
SIRstrand = deepcopy(SEIRstrand)
SIRstrand[:name] = "2.06-SIR"
SIRstrand[:incubationMean] = "1" #1 second incubation
SIRstrand[:incubationShape] = "10000"
SIRstrand
# Out:
# Dict{Symbol, String} with 9 entries:
#   :infectionMean         => "432000"
#   :endTime               => "2021-11-04T20:00:00Z"
#   :incubationShape       => "10000"
#   :minimumAppVersion     => "60"
#   :name                  => "2.06-SIR"
#   :seedingProbability    => "0.1"
#   :infectiousPeriodShape => "3"
#   :seedTime              => "2021-09-15T21:00:00Z"
#   :incubationMean        => "1"

# %%
SEIRstrandShortDuration = deepcopy(SEIRstrand)
SEIRstrandShortDuration[:name] = SEIRstrandShortDuration[:name]*"-days5";
SEIRstrandShortDuration
# Out:
# Dict{Symbol, String} with 9 entries:
#   :infectionMean         => "432000"
#   :endTime               => "2021-11-04T20:00:00Z"
#   :incubationShape       => "3"
#   :minimumAppVersion     => "60"
#   :name                  => "2.06-SEIR-days5"
#   :seedingProbability    => "0.1"
#   :infectiousPeriodShape => "3"
#   :seedTime              => "2021-09-15T21:00:00Z"
#   :incubationMean        => "172800"

# %%
SEIRstrandLongDuration = deepcopy(SEIRstrand)
SEIRstrandLongDuration[:infectionMean] = "864000" #10 days 
SEIRstrandLongDuration[:name] = SEIRstrandLongDuration[:name]*"-days10";
SEIRstrandLongDuration
# Out:
# Dict{Symbol, String} with 9 entries:
#   :infectionMean         => "864000"
#   :endTime               => "2021-11-04T20:00:00Z"
#   :incubationShape       => "3"
#   :minimumAppVersion     => "60"
#   :name                  => "2.06-SEIR-days10"
#   :seedingProbability    => "0.1"
#   :infectiousPeriodShape => "3"
#   :seedTime              => "2021-09-15T21:00:00Z"
#   :incubationMean        => "172800"

# %%
SIRstrandShortDuration = deepcopy(SIRstrand)
SIRstrandShortDuration[:name] = SIRstrandShortDuration[:name]*"-days5";
SIRstrandShortDuration
# Out:
# Dict{Symbol, String} with 9 entries:
#   :infectionMean         => "432000"
#   :endTime               => "2021-11-04T20:00:00Z"
#   :incubationShape       => "10000"
#   :minimumAppVersion     => "60"
#   :name                  => "2.06-SIR-days5"
#   :seedingProbability    => "0.1"
#   :infectiousPeriodShape => "3"
#   :seedTime              => "2021-09-15T21:00:00Z"
#   :incubationMean        => "1"

# %%
SIRstrandLongDuration = deepcopy(SIRstrand)
SIRstrandLongDuration[:infectionMean] = "864000" #10 days 
SIRstrandLongDuration[:name] = SIRstrandLongDuration[:name]*"-days10";
SIRstrandLongDuration
# Out:
# Dict{Symbol, String} with 9 entries:
#   :infectionMean         => "864000"
#   :endTime               => "2021-11-04T20:00:00Z"
#   :incubationShape       => "10000"
#   :minimumAppVersion     => "60"
#   :name                  => "2.06-SIR-days10"
#   :seedingProbability    => "0.1"
#   :infectiousPeriodShape => "3"
#   :seedTime              => "2021-09-15T21:00:00Z"
#   :incubationMean        => "1"

# %%
#An array that will hold all strands
strands = Array{Dict{Symbol,String}}(undef,0)
append!(strands, createRepeats(SIstrand, numRepeats_SI_SEI))
append!(strands, createRepeats(SEIstrand, numRepeats_SI_SEI))
append!(strands, createRepeats(SEIRstrandShortDuration, numRepeats_SIR_SEIR))
append!(strands, createRepeats(SEIRstrandLongDuration, numRepeats_SIR_SEIR))
append!(strands, createRepeats(SIRstrandShortDuration, numRepeats_SIR_SEIR))
append!(strands, createRepeats(SIRstrandLongDuration, numRepeats_SIR_SEIR));

# %%
length(strands)
# Out:
# 600

# %%
function strandJSON(sd::Dict{Symbol,String})
    str = """
        {\"name\":\"$(sd[:name])\",
         \"seedingProbability\":\"$(sd[:seedingProbability])\",
         \"infectionProbabilityMapP\":\"$(sd[:strength])\",
         \"infectionProbabilityMapK\":\"$(sd[:radius])\",
         \"infectionProbabilityMapL\":\"1000000\",
         \"incubationPeriodMeanSec\":\"$(sd[:incubationMean])\",
         \"incubationPeriodShape\":\"$(sd[:incubationShape])\",
         \"infectiousPeriodMeanSec\":\"$(sd[:infectionMean])\",
         \"infectiousPeriodShape\":\"$(sd[:infectiousPeriodShape])\",
         \"startTime\":\"$(sd[:seedTime])\",
         \"endTime\":\"$(sd[:endTime])\",
         \"minimumAppVersion\":\"$(sd[:minimumAppVersion])\"}
    """
    join(map(x -> isspace(str[x]) ? "" : str[x], 1:length(str))) #how the $%@$% to remove white space in Julia strings?
end

strandStrings = strandJSON.(strands)
if length(filter(x->x=="strands2_06.txt",map(abspath, readdir())))!=0
    rm("strands2_06.txt") #remove the text file in the working directory if exists
end
touch("strands2_06.txt") #create the text file in the working directory
open("strands2_06.txt","w") do file 
    newID = 3670 #last strand in system
    for s in strandStrings
        newID +=1
        write(file,"$newID: $s\n")
        println("$newID: $s\n")
    end
end
# Out:
# 3671: {"name":"2.06-SI-(0.08,30)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"30","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3672: {"name":"2.06-SI-(0.08,30)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"30","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3673: {"name":"2.06-SI-(0.08,35)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"35","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3674: {"name":"2.06-SI-(0.08,35)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"35","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3675: {"name":"2.06-SI-(0.08,40)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"40","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3676: {"name":"2.06-SI-(0.08,40)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"40","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3677: {"name":"2.06-SI-(0.08,45)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"45","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3678: {"name":"2.06-SI-(0.08,45)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"45","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3679: {"name":"2.06-SI-(0.08,50)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"50","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3680: {"name":"2.06-SI-(0.08,50)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"50","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3681: {"name":"2.06-SI-(0.08,60)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"60","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3682: {"name":"2.06-SI-(0.08,60)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"60","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3683: {"name":"2.06-SI-(0.08,70)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"70","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3684: {"name":"2.06-SI-(0.08,70)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"70","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3685: {"name":"2.06-SI-(0.08,80)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"80","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3686: {"name":"2.06-SI-(0.08,80)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"80","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3687: {"name":"2.06-SI-(0.08,90)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"90","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3688: {"name":"2.06-SI-(0.08,90)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"90","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3689: {"name":"2.06-SI-(0.08,100)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"100","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3690: {"name":"2.06-SI-(0.08,100)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"100","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3691: {"name":"2.06-SI-(0.16,30)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"30","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3692: {"name":"2.06-SI-(0.16,30)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"30","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3693: {"name":"2.06-SI-(0.16,35)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"35","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3694: {"name":"2.06-SI-(0.16,35)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"35","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3695: {"name":"2.06-SI-(0.16,40)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"40","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3696: {"name":"2.06-SI-(0.16,40)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"40","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
# 3697: {"name":"2.06-SI-(0.16,45)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"45","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3698: {"name":"2.06-SI-(0.16,45)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"45","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3699: {"name":"2.06-SI-(0.16,50)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"50","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3700: {"name":"2.06-SI-(0.16,50)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"50","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3701: {"name":"2.06-SI-(0.16,60)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"60","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3702: {"name":"2.06-SI-(0.16,60)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"60","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3703: {"name":"2.06-SI-(0.16,70)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"70","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3704: {"name":"2.06-SI-(0.16,70)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"70","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3705: {"name":"2.06-SI-(0.16,80)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"80","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3706: {"name":"2.06-SI-(0.16,80)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"80","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3707: {"name":"2.06-SI-(0.16,90)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"90","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3708: {"name":"2.06-SI-(0.16,90)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"90","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3709: {"name":"2.06-SI-(0.16,100)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"100","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3710: {"name":"2.06-SI-(0.16,100)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"100","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3711: {"name":"2.06-SI-(0.48,30)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"30","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3712: {"name":"2.06-SI-(0.48,30)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"30","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3713: {"name":"2.06-SI-(0.48,35)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"35","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3714: {"name":"2.06-SI-(0.48,35)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"35","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3715: {"name":"2.06-SI-(0.48,40)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"40","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3716: {"name":"2.06-SI-(0.48,40)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"40","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3717: {"name":"2.06-SI-(0.48,45)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"45","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3718: {"name":"2.06-SI-(0.48,45)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"45","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3719: {"name":"2.06-SI-(0.48,50)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"50","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3720: {"name":"2.06-SI-(0.48,50)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"50","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3721: {"name":"2.06-SI-(0.48,60)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"60","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3722: {"name":"2.06-SI-(0.48,60)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"60","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
# 3723: {"name":"2.06-SI-(0.48,70)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"70","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3724: {"name":"2.06-SI-(0.48,70)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"70","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3725: {"name":"2.06-SI-(0.48,80)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"80","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3726: {"name":"2.06-SI-(0.48,80)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"80","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3727: {"name":"2.06-SI-(0.48,90)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"90","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3728: {"name":"2.06-SI-(0.48,90)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"90","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3729: {"name":"2.06-SI-(0.48,100)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"100","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3730: {"name":"2.06-SI-(0.48,100)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"100","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3731: {"name":"2.06-SEI-(0.08,30)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"30","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3732: {"name":"2.06-SEI-(0.08,30)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"30","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3733: {"name":"2.06-SEI-(0.08,35)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"35","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3734: {"name":"2.06-SEI-(0.08,35)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"35","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3735: {"name":"2.06-SEI-(0.08,40)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"40","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3736: {"name":"2.06-SEI-(0.08,40)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"40","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3737: {"name":"2.06-SEI-(0.08,45)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"45","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3738: {"name":"2.06-SEI-(0.08,45)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"45","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3739: {"name":"2.06-SEI-(0.08,50)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"50","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3740: {"name":"2.06-SEI-(0.08,50)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"50","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3741: {"name":"2.06-SEI-(0.08,60)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"60","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3742: {"name":"2.06-SEI-(0.08,60)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"60","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3743: {"name":"2.06-SEI-(0.08,70)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"70","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3744: {"name":"2.06-SEI-(0.08,70)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"70","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3745: {"name":"2.06-SEI-(0.08,80)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"80","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3746: {"name":"2.06-SEI-(0.08,80)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"80","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3747: {"name":"2.06-SEI-(0.08,90)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"90","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3748: {"name":"2.06-SEI-(0.08,90)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"90","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
# 3749: {"name":"2.06-SEI-(0.08,100)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"100","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3750: {"name":"2.06-SEI-(0.08,100)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.08","infectionProbabilityMapK":"100","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3751: {"name":"2.06-SEI-(0.16,30)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"30","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3752: {"name":"2.06-SEI-(0.16,30)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"30","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3753: {"name":"2.06-SEI-(0.16,35)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"35","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3754: {"name":"2.06-SEI-(0.16,35)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"35","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3755: {"name":"2.06-SEI-(0.16,40)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"40","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3756: {"name":"2.06-SEI-(0.16,40)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"40","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3757: {"name":"2.06-SEI-(0.16,45)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"45","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3758: {"name":"2.06-SEI-(0.16,45)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"45","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3759: {"name":"2.06-SEI-(0.16,50)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"50","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3760: {"name":"2.06-SEI-(0.16,50)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"50","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3761: {"name":"2.06-SEI-(0.16,60)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"60","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3762: {"name":"2.06-SEI-(0.16,60)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"60","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3763: {"name":"2.06-SEI-(0.16,70)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"70","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3764: {"name":"2.06-SEI-(0.16,70)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"70","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3765: {"name":"2.06-SEI-(0.16,80)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"80","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3766: {"name":"2.06-SEI-(0.16,80)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"80","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3767: {"name":"2.06-SEI-(0.16,90)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"90","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3768: {"name":"2.06-SEI-(0.16,90)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"90","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3769: {"name":"2.06-SEI-(0.16,100)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"100","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3770: {"name":"2.06-SEI-(0.16,100)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.16","infectionProbabilityMapK":"100","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3771: {"name":"2.06-SEI-(0.48,30)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"30","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3772: {"name":"2.06-SEI-(0.48,30)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"30","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3773: {"name":"2.06-SEI-(0.48,35)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"35","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3774: {"name":"2.06-SEI-(0.48,35)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"35","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
# 3775: {"name":"2.06-SEI-(0.48,40)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"40","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3776: {"name":"2.06-SEI-(0.48,40)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"40","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3777: {"name":"2.06-SEI-(0.48,45)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"45","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3778: {"name":"2.06-SEI-(0.48,45)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"45","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3779: {"name":"2.06-SEI-(0.48,50)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"50","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3780: {"name":"2.06-SEI-(0.48,50)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"50","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3781: {"name":"2.06-SEI-(0.48,60)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"60","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3782: {"name":"2.06-SEI-(0.48,60)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"60","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3783: {"name":"2.06-SEI-(0.48,70)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"70","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3784: {"name":"2.06-SEI-(0.48,70)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"70","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3785: {"name":"2.06-SEI-(0.48,80)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"80","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3786: {"name":"2.06-SEI-(0.48,80)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"80","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3787: {"name":"2.06-SEI-(0.48,90)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"90","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3788: {"name":"2.06-SEI-(0.48,90)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"90","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3789: {"name":"2.06-SEI-(0.48,100)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"100","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 3790: {"name":"2.06-SEI-(0.48,100)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"100","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"172800","incubationPeriodShape":"3","infectiousPeriodMeanSec":"31536000","infectiousPeriodShape":"10000","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# ...
#
# 4232: {"name":"2.06-SIR-days10-(0.48,30)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"30","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 4233: {"name":"2.06-SIR-days10-(0.48,30)-repeat3","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"30","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 4234: {"name":"2.06-SIR-days10-(0.48,30)-repeat4","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"30","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 4235: {"name":"2.06-SIR-days10-(0.48,35)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"35","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 4236: {"name":"2.06-SIR-days10-(0.48,35)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"35","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 4237: {"name":"2.06-SIR-days10-(0.48,35)-repeat3","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"35","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 4238: {"name":"2.06-SIR-days10-(0.48,35)-repeat4","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"35","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 4239: {"name":"2.06-SIR-days10-(0.48,40)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"40","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 4240: {"name":"2.06-SIR-days10-(0.48,40)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"40","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 4241: {"name":"2.06-SIR-days10-(0.48,40)-repeat3","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"40","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 4242: {"name":"2.06-SIR-days10-(0.48,40)-repeat4","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"40","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
# 4243: {"name":"2.06-SIR-days10-(0.48,45)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"45","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 4244: {"name":"2.06-SIR-days10-(0.48,45)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"45","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 4245: {"name":"2.06-SIR-days10-(0.48,45)-repeat3","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"45","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 4246: {"name":"2.06-SIR-days10-(0.48,45)-repeat4","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"45","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 4247: {"name":"2.06-SIR-days10-(0.48,50)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"50","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 4248: {"name":"2.06-SIR-days10-(0.48,50)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"50","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 4249: {"name":"2.06-SIR-days10-(0.48,50)-repeat3","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"50","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 4250: {"name":"2.06-SIR-days10-(0.48,50)-repeat4","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"50","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 4251: {"name":"2.06-SIR-days10-(0.48,60)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"60","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 4252: {"name":"2.06-SIR-days10-(0.48,60)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"60","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 4253: {"name":"2.06-SIR-days10-(0.48,60)-repeat3","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"60","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 4254: {"name":"2.06-SIR-days10-(0.48,60)-repeat4","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"60","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 4255: {"name":"2.06-SIR-days10-(0.48,70)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"70","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 4256: {"name":"2.06-SIR-days10-(0.48,70)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"70","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 4257: {"name":"2.06-SIR-days10-(0.48,70)-repeat3","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"70","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 4258: {"name":"2.06-SIR-days10-(0.48,70)-repeat4","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"70","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 4259: {"name":"2.06-SIR-days10-(0.48,80)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"80","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 4260: {"name":"2.06-SIR-days10-(0.48,80)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"80","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 4261: {"name":"2.06-SIR-days10-(0.48,80)-repeat3","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"80","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 4262: {"name":"2.06-SIR-days10-(0.48,80)-repeat4","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"80","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 4263: {"name":"2.06-SIR-days10-(0.48,90)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"90","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 4264: {"name":"2.06-SIR-days10-(0.48,90)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"90","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 4265: {"name":"2.06-SIR-days10-(0.48,90)-repeat3","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"90","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 4266: {"name":"2.06-SIR-days10-(0.48,90)-repeat4","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"90","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 4267: {"name":"2.06-SIR-days10-(0.48,100)-repeat1","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"100","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 4268: {"name":"2.06-SIR-days10-(0.48,100)-repeat2","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"100","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
# 4269: {"name":"2.06-SIR-days10-(0.48,100)-repeat3","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"100","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
#
# 4270: {"name":"2.06-SIR-days10-(0.48,100)-repeat4","seedingProbability":"0.1","infectionProbabilityMapP":"0.48","infectionProbabilityMapK":"100","infectionProbabilityMapL":"1000000","incubationPeriodMeanSec":"1","incubationPeriodShape":"10000","infectiousPeriodMeanSec":"864000","infectiousPeriodShape":"3","startTime":"2021-09-15T21:00:00Z","endTime":"2021-11-04T20:00:00Z","minimumAppVersion":"60"}
